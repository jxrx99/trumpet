# %%
from tensorflow.keras.models import load_model
from src.modelling.model import twitter_model, gen_vocab, generate_text_sequences
from src.datapipeline.datapipeline import Datapipeline
import numpy as np
import pandas as pd


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dpl = Datapipeline(r'./data/raw/realdonaldtrump.csv')
dpl.transform()
train, val = dpl.split_data()

# %%
trump_model = twitter_model(r'./data/raw/glove.6B.100d.txt')
trump_model.build_model(train.values)
# Out:
# Converted 13125 words (1273 misses)
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 100)         1440200
# _________________________________________________________________
# bidirectional (Bidirectional (None, 200)               160800
# _________________________________________________________________
# dense (Dense)                (None, 14400)             2894400
# =================================================================
# Total params: 4,495,400
# Trainable params: 3,055,200
# Non-trainable params: 1,440,200
# _________________________________________________________________

# %%
trump_model.get_train_data(train.values)
# Out:
# WARNING:tensorflow:From C:\Users\neoce\Google Drive\DataScience\AIAP Stuff\AIAP Batch 6 Assignments\team5\src\modelling\model.py:173: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.

# %%
x, y = trump_model.get_data()

# %%
vocab, vec = trump_model.get_vocab()

# %%
loaded_model = load_model("trump_bot.h5")

# %%
x_sample = x[:5]

# %%
preds = loaded_model.predict(x_sample)

# %%
np.argmax(preds, axis = 1)
# Out:
# array([ 4, 24, 51, 10, 12], dtype=int64)

# %% [markdown]
# Jin Segment 2 Stacked Bidir Model

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from src.modelling.model import gen_vocab, generate_text_sequences
from src.datapipeline.datapipeline import Datapipeline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dpl = Datapipeline(r'./data/realdonaldtrump.csv')
dpl.transform()
train, val = dpl.split_data()

# %%
model = load_model('trump_bot_bidirstack.h5')

# %%
vocab, vectorizer = gen_vocab(train.values)

# %%
x_val, y_val = generate_text_sequences(val.values, 5, vocab)

# %%
x_input_val = vectorizer.apply(list(map(lambda x: ' '.join(x), x_val)))
x_input_val = tf.gather(x_input_val, [0,1,2,3,4], axis=1)

# %%
x_input_val
# Out:
# <tf.Tensor: shape=(74079, 5), dtype=int64, numpy=
# array([[8022,  549,   68,   16,   83],
#        [ 549,   68,   16,   83,    9],
#        [  68,   16,   83,    9, 5574],
#        ...,
#        [5574,    4,   13,   16,  280],
#        [   4,   13,   16,  280,    6],
#        [  13,   16,  280,    6,  620]], dtype=int64)>

# %%
y_pred_val = model.predict(x_input_val)

# %%
index_label = np.argmax(y_pred_val, axis = 1)

output_word = []

for idx in index_label:
    output_word.append(vocab[idx])

# %%
y_pred_val.shape
# Out:
# (74079, 14400)

# %%
x_val
# Out:
# [['defunding', 'police', 'would', 'be', 'good'],
#  ['police', 'would', 'be', 'good', 'for'],
#  ['would', 'be', 'good', 'for', '<Unknown>'],
#  ['the', 'trade', 'deficit', 'rose', 'to'],
#  ['trade', 'deficit', 'rose', 'to', 'a'],
#  ['deficit', 'rose', 'to', 'a', 'yr'],
#  ['rose', 'to', 'a', 'yr', 'high'],
#  ['to', 'a', 'yr', 'high', 'thanks'],
#  ['a', 'yr', 'high', 'thanks', 'to'],
#  ['yr', 'high', 'thanks', 'to', 'horrible'],
#  ['high', 'thanks', 'to', 'horrible', 'trade'],
#  ['thanks', 'to', 'horrible', 'trade', 'policies'],
#  ['to', 'horrible', 'trade', 'policies', 'clinton'],
#  ['horrible', 'trade', 'policies', 'clinton', 'supports'],
#  ['trade', 'policies', 'clinton', 'supports', 'i'],
#  ['policies', 'clinton', 'supports', 'i', 'will'],
#  ['clinton', 'supports', 'i', 'will', 'fix'],
#  ['supports', 'i', 'will', 'fix', 'it'],
#  ['i', 'will', 'fix', 'it', 'fast'],
#  ['you', 'must', 'be', 'doing', 'something'],
#  ['must', 'be', 'doing', 'something', 'right'],
#  ['be', 'doing', 'something', 'right', 'cause'],
#  ['doing', 'something', 'right', 'cause', 'the'],
#  ['something', 'right', 'cause', 'the', 'left'],
#  ['right', 'cause', 'the', 'left', 'has'],
#  ['cause', 'the', 'left', 'has', '<Unknown>'],
#  ['the', 'left', 'has', '<Unknown>', 'the'],
#  ['left', 'has', '<Unknown>', 'the', 'war'],
#  ['has', '<Unknown>', 'the', 'war', '<Unknown>'],
#  ['<Unknown>', 'the', 'war', '<Unknown>', 'stay'],
#  ['the', 'war', '<Unknown>', 'stay', 'strong'],
#  ['war', '<Unknown>', 'stay', 'strong', 'in'],
#  ['<Unknown>', 'stay', 'strong', 'in', 'your'],
#  ['stay', 'strong', 'in', 'your', 'convictions'],
#  ['strong', 'in', 'your', 'convictions', 'we'],
#  ['in', 'your', 'convictions', 'we', 'love'],
#  ['can', 't', 'wait', 'for', 'you'],
#  ['t', 'wait', 'for', 'you', 'to'],
#  ['wait', 'for', 'you', 'to', 'take'],
#  ['for', 'you', 'to', 'take', 'the'],
#  ['you', 'to', 'take', 'the', 'white'],
#  ['to', 'take', 'the', 'white', 'house'],
#  ['take', 'the', 'white', 'house', 'our'],
#  ['the', 'white', 'house', 'our', 'country'],
#  ['white', 'house', 'our', 'country', 'will'],
#  ['house', 'our', 'country', 'will', 'once'],
#  ['our', 'country', 'will', 'once', 'again'],
#  ['country', 'will', 'once', 'again', 'be'],
#  ['will', 'once', 'again', 'be', 'strong'],
#  ['once', 'again', 'be', 'strong', 'sorry'],
#  ['again', 'be', 'strong', 'sorry', 'jebbush'],
#  ['be', 'strong', 'sorry', 'jebbush', 'but'],
#  ['strong', 'sorry', 'jebbush', 'but', 'you'],
#  ['sorry', 'jebbush', 'but', 'you', 'got'],
#  ['jebbush', 'but', 'you', 'got', 'no'],
#  ['the', 'rules', 'did', 'change', 'in'],
#  ['rules', 'did', 'change', 'in', 'colorado'],
#  ['did', 'change', 'in', 'colorado', 'shortly'],
#  ['change', 'in', 'colorado', 'shortly', 'after'],
#  ['in', 'colorado', 'shortly', 'after', 'i'],
#  ['colorado', 'shortly', 'after', 'i', 'entered'],
#  ['shortly', 'after', 'i', 'entered', 'the'],
#  ['after', 'i', 'entered', 'the', 'race'],
#  ['i', 'entered', 'the', 'race', 'in'],
#  ['entered', 'the', 'race', 'in', 'june'],
#  ['the', 'race', 'in', 'june', 'because'],
#  ['race', 'in', 'june', 'because', 'the'],
#  ['in', 'june', 'because', 'the', 'pols'],
#  ['june', 'because', 'the', 'pols', 'and'],
#  ['because', 'the', 'pols', 'and', 'their'],
#  ['the', 'pols', 'and', 'their', 'bosses'],
#  ['pols', 'and', 'their', 'bosses', 'knew'],
#  ['and', 'their', 'bosses', 'knew', 'i'],
#  ['their', 'bosses', 'knew', 'i', 'would'],
#  ['bosses', 'knew', 'i', 'would', 'win'],
#  ['knew', 'i', 'would', 'win', 'with'],
#  ['i', 'would', 'win', 'with', 'the'],
#  ['happy', 'birthday', 'to', 'our', 'great'],
#  ['birthday', 'to', 'our', 'great', 'mike'],
#  ['great', 'republican', 'vote', 'today', 'on'],
#  ['republican', 'vote', 'today', 'on', 'disaster'],
#  ['vote', 'today', 'on', 'disaster', 'relief'],
#  ['today', 'on', 'disaster', 'relief', 'bill'],
#  ['on', 'disaster', 'relief', 'bill', 'we'],
#  ['disaster', 'relief', 'bill', 'we', 'will'],
#  ['relief', 'bill', 'we', 'will', 'now'],
#  ['bill', 'we', 'will', 'now', 'work'],
#  ['we', 'will', 'now', 'work', 'out'],
#  ['will', 'now', 'work', 'out', 'a'],
#  ['now', 'work', 'out', 'a', 'bipartisan'],
#  ['work', 'out', 'a', 'bipartisan', 'solution'],
#  ['out', 'a', 'bipartisan', 'solution', 'that'],
#  ['a', 'bipartisan', 'solution', 'that', 'gets'],
#  ['bipartisan', 'solution', 'that', 'gets', 'relief'],
#  ['solution', 'that', 'gets', 'relief', 'for'],
#  ['that', 'gets', 'relief', 'for', 'our'],
#  ['gets', 'relief', 'for', 'our', 'great'],
#  ['relief', 'for', 'our', 'great', 'states'],
#  ['for', 'our', 'great', 'states', 'and'],
#  ['our', 'great', 'states', 'and', 'farmers'],
#  ['great', 'states', 'and', 'farmers', 'thank'],
#  ['states', 'and', 'farmers', 'thank', 'you'],
#  ['and', 'farmers', 'thank', 'you', 'to'],
#  ['farmers', 'thank', 'you', 'to', 'all'],
#  ['thank', 'you', 'to', 'all', 'get'],
#  ['you', 'to', 'all', 'get', 'me'],
#  ['to', 'all', 'get', 'me', 'a'],
#  ['all', 'get', 'me', 'a', 'bill'],
#  ['get', 'me', 'a', 'bill', 'that'],
#  ['me', 'a', 'bill', 'that', 'i'],
#  ['a', 'bill', 'that', 'i', 'can'],
#  ['bill', 'that', 'i', 'can', 'quickly'],
#  ['all', 'things', 'that', 'i', 'have'],
#  ['things', 'that', 'i', 'have', 'gotten'],
#  ['that', 'i', 'have', 'gotten', 'done'],
#  ['i', 'have', 'gotten', 'done', 'including'],
#  ['have', 'gotten', 'done', 'including', 'criminal'],
#  ['gotten', 'done', 'including', 'criminal', 'justice'],
#  ['we', 'need', 'trump', 'more', 'then'],
#  ['need', 'trump', 'more', 'then', 'ever'],
#  ['trump', 'more', 'then', 'ever', 'megan'],
#  ['more', 'then', 'ever', 'megan', 'please'],
#  ['then', 'ever', 'megan', 'please', 'don'],
#  ['ever', 'megan', 'please', 'don', 't'],
#  ['megan', 'please', 'don', 't', 'lose'],
#  ['please', 'don', 't', 'lose', 'it'],
#  ['don', 't', 'lose', 'it', 'for'],
#  ['t', 'lose', 'it', 'for', 'america'],
#  ['lose', 'it', 'for', 'america', 'for'],
#  ['former', 'democrat', 'senator', 'harry', 'reid'],
#  ['democrat', 'senator', 'harry', 'reid', 'just'],
#  ['senator', 'harry', 'reid', 'just', 'stated'],
#  ['harry', 'reid', 'just', 'stated', 'that'],
#  ['reid', 'just', 'stated', 'that', 'donald'],
#  ['just', 'stated', 'that', 'donald', 'trump'],
#  ['stated', 'that', 'donald', 'trump', 'is'],
#  ['that', 'donald', 'trump', 'is', 'very'],
#  ['donald', 'trump', 'is', 'very', 'smart'],
#  ['trump', 'is', 'very', 'smart', 'much'],
#  ['is', 'very', 'smart', 'much', 'more'],
#  ['very', 'smart', 'much', 'more', 'popular'],
#  ['smart', 'much', 'more', 'popular', 'than'],
#  ['much', 'more', 'popular', 'than', 'people'],
#  ['more', 'popular', 'than', 'people', 'think'],
#  ['popular', 'than', 'people', 'think', 'is'],
#  ['than', 'people', 'think', 'is', '<Unknown>'],
#  ['people', 'think', 'is', '<Unknown>', 'and'],
#  ['think', 'is', '<Unknown>', 'and', 'will'],
#  ['is', '<Unknown>', 'and', 'will', 'be'],
#  ['<Unknown>', 'and', 'will', 'be', 'hard'],
#  ['and', 'will', 'be', 'hard', 'to'],
#  ['will', 'be', 'hard', 'to', 'beat'],
#  ['be', 'hard', 'to', 'beat', 'in'],
#  ['hard', 'to', 'beat', 'in', 'the'],
#  ['to', 'beat', 'in', 'the', 'election'],
#  ['beat', 'in', 'the', 'election', 'thank'],
#  ['in', 'the', 'election', 'thank', 'you'],
#  ['the', 'election', 'thank', 'you', 'harry'],
#  ['election', 'thank', 'you', 'harry', 'i'],
#  ['there', 'is', 'only', 'one', 'way'],
#  ['is', 'only', 'one', 'way', 'to'],
#  ['only', 'one', 'way', 'to', 'stop'],
#  ['one', 'way', 'to', 'stop', 'this'],
#  ['way', 'to', 'stop', 'this', 'democrat'],
#  ['to', 'stop', 'this', 'democrat', 'led'],
#  ['stop', 'this', 'democrat', 'led', 'assault'],
#  ['this', 'democrat', 'led', 'assault', 'on'],
#  ['democrat', 'led', 'assault', 'on', 'our'],
#  ['led', 'assault', 'on', 'our', 'sovereignty'],
#  ['assault', 'on', 'our', 'sovereignty', 'you'],
#  ['on', 'our', 'sovereignty', 'you', 'have'],
#  ['our', 'sovereignty', 'you', 'have', 'to'],
#  ['sovereignty', 'you', 'have', 'to', 'vote'],
#  ['you', 'have', 'to', 'vote', 'republican'],
#  ['have', 'to', 'vote', 'republican', 'tomorrow'],
#  ['to', 'vote', 'republican', 'tomorrow', 'polling'],
#  ['our', 'country', 'is', 'the', 'envy'],
#  ['country', 'is', 'the', 'envy', 'of'],
#  ['is', 'the', 'envy', 'of', 'the'],
#  ['the', 'envy', 'of', 'the', 'world'],
#  ['envy', 'of', 'the', 'world', 'thank'],
#  ['of', 'the', 'world', 'thank', 'you'],
#  ['the', 'world', 'thank', 'you', 'mr'],
#  ['on', 'to', 'age', 'limits', 'watching'],
#  ['to', 'age', 'limits', 'watching', 'court'],
#  ['age', 'limits', 'watching', 'court', 'cases'],
#  ['limits', 'watching', 'court', 'cases', 'and'],
#  ['watching', 'court', 'cases', 'and', 'rulings'],
#  ['court', 'cases', 'and', 'rulings', 'before'],
#  ['cases', 'and', 'rulings', 'before', 'acting'],
#  ['and', 'rulings', 'before', 'acting', 'states'],
#  ['rulings', 'before', 'acting', 'states', 'are'],
#  ['before', 'acting', 'states', 'are', 'making'],
#  ['acting', 'states', 'are', 'making', 'this'],
#  ['states', 'are', 'making', 'this', 'decision'],
#  ['are', 'making', 'this', 'decision', 'things'],
#  ['making', 'this', 'decision', 'things', 'are'],
#  ['this', 'decision', 'things', 'are', 'moving'],
#  ['decision', 'things', 'are', 'moving', 'rapidly'],
#  ['things', 'are', 'moving', 'rapidly', 'on'],
#  ['are', 'moving', 'rapidly', 'on', 'this'],
#  ['moving', 'rapidly', 'on', 'this', 'but'],
#  ['rapidly', 'on', 'this', 'but', 'not'],
#  ['on', 'this', 'but', 'not', 'much'],
#  ['this', 'but', 'not', 'much', 'political'],
#  ['but', 'not', 'much', 'political', 'support'],
#  ['not', 'much', 'political', 'support', 'to'],
#  ['much', 'political', 'support', 'to', 'put'],
#  ['political', 'support', 'to', 'put', 'it'],
#  ['we', 'are', 'getting', 'ms', 'gang'],
#  ['are', 'getting', 'ms', 'gang', 'members'],
#  ['getting', 'ms', 'gang', 'members', 'and'],
#  ['ms', 'gang', 'members', 'and', 'many'],
#  ['gang', 'members', 'and', 'many', 'other'],
#  ['members', 'and', 'many', 'other', 'people'],
#  ['and', 'many', 'other', 'people', 'that'],
#  ['many', 'other', 'people', 'that', 'shouldn'],
#  ['other', 'people', 'that', 'shouldn', 't'],
#  ['people', 'that', 'shouldn', 't', 'be'],
#  ['that', 'shouldn', 't', 'be', 'here'],
#  ['shouldn', 't', 'be', 'here', 'out'],
#  ['t', 'be', 'here', 'out', 'of'],
#  ['be', 'here', 'out', 'of', 'our'],
#  ['as', 'president', 'i', 'have', 'an'],
#  ['president', 'i', 'have', 'an', 'obligation'],
#  ['i', 'have', 'an', 'obligation', 'to'],
#  ['have', 'an', 'obligation', 'to', 'end'],
#  ['an', 'obligation', 'to', 'end', 'corruption'],
#  ['obligation', 'to', 'end', 'corruption', 'even'],
#  ['to', 'end', 'corruption', 'even', 'if'],
#  ['end', 'corruption', 'even', 'if', 'that'],
#  ['corruption', 'even', 'if', 'that', 'means'],
#  ['even', 'if', 'that', 'means', 'requesting'],
#  ['if', 'that', 'means', 'requesting', 'the'],
#  ['that', 'means', 'requesting', 'the', 'help'],
#  ['means', 'requesting', 'the', 'help', 'of'],
#  ['requesting', 'the', 'help', 'of', 'a'],
#  ['the', 'help', 'of', 'a', 'foreign'],
#  ['help', 'of', 'a', 'foreign', 'country'],
#  ['of', 'a', 'foreign', 'country', 'or'],
#  ['a', 'foreign', 'country', 'or', 'countries'],
#  ['foreign', 'country', 'or', 'countries', 'it'],
#  ['country', 'or', 'countries', 'it', 'is'],
#  ['or', 'countries', 'it', 'is', 'done'],
#  ['countries', 'it', 'is', 'done', 'all'],
#  ['it', 'is', 'done', 'all', 'the'],
#  ['is', 'done', 'all', 'the', 'time'],
#  ['done', 'all', 'the', 'time', 'this'],
#  ['all', 'the', 'time', 'this', 'has'],
#  ['the', 'time', 'this', 'has', 'nothing'],
#  ['time', 'this', 'has', 'nothing', 'to'],
#  ['this', 'has', 'nothing', 'to', 'do'],
#  ['has', 'nothing', 'to', 'do', 'with'],
#  ['nothing', 'to', 'do', 'with', 'politics'],
#  ['to', 'do', 'with', 'politics', 'or'],
#  ['do', 'with', 'politics', 'or', 'a'],
#  ['with', 'politics', 'or', 'a', 'political'],
#  ['politics', 'or', 'a', 'political', 'campaign'],
#  ['or', 'a', 'political', 'campaign', 'against'],
#  ['a', 'political', 'campaign', 'against', 'the'],
#  ['political', 'campaign', 'against', 'the', 'bidens'],
#  ['campaign', 'against', 'the', 'bidens', 'this'],
#  ['against', 'the', 'bidens', 'this', 'does'],
#  ['the', 'bidens', 'this', 'does', 'have'],
#  ['bidens', 'this', 'does', 'have', 'to'],
#  ['this', 'does', 'have', 'to', 'do'],
#  ['does', 'have', 'to', 'do', 'with'],
#  ['have', 'to', 'do', 'with', 'their'],
#  ['extremism', 'and', 'all', 'reference', 'was'],
#  ['and', 'all', 'reference', 'was', '<Unknown>'],
#  ['all', 'reference', 'was', '<Unknown>', 'to'],
#  ['reference', 'was', '<Unknown>', 'to', 'qatar'],
#  ['was', '<Unknown>', 'to', 'qatar', 'perhaps'],
#  ['<Unknown>', 'to', 'qatar', 'perhaps', 'this'],
#  ['to', 'qatar', 'perhaps', 'this', 'will'],
#  ['qatar', 'perhaps', 'this', 'will', 'be'],
#  ['perhaps', 'this', 'will', 'be', 'the'],
#  ['this', 'will', 'be', 'the', 'beginning'],
#  ['will', 'be', 'the', 'beginning', 'of'],
#  ['be', 'the', 'beginning', 'of', 'the'],
#  ['the', 'beginning', 'of', 'the', 'end'],
#  ['beginning', 'of', 'the', 'end', 'to'],
#  ['of', 'the', 'end', 'to', 'the'],
#  ['the', 'end', 'to', 'the', 'horror'],
#  ['end', 'to', 'the', 'horror', 'of'],
#  ['to', 'testify', 'are', 'they', 'looking'],
#  ['testify', 'are', 'they', 'looking', 'for'],
#  ['are', 'they', 'looking', 'for', 'a'],
#  ['they', 'looking', 'for', 'a', 'redo'],
#  ['looking', 'for', 'a', 'redo', 'because'],
#  ['for', 'a', 'redo', 'because', 'they'],
#  ['a', 'redo', 'because', 'they', 'hated'],
#  ['redo', 'because', 'they', 'hated', 'seeing'],
#  ['because', 'they', 'hated', 'seeing', 'the'],
#  ['they', 'hated', 'seeing', 'the', 'strong'],
#  ['hated', 'seeing', 'the', 'strong', 'no'],
#  ['seeing', 'the', 'strong', 'no', 'collusion'],
#  ['the', 'strong', 'no', 'collusion', 'conclusion'],
#  ['strong', 'no', 'collusion', 'conclusion', 'there'],
#  ['no', 'collusion', 'conclusion', 'there', 'was'],
#  ['collusion', 'conclusion', 'there', 'was', 'no'],
#  ['conclusion', 'there', 'was', 'no', 'crime'],
#  ['there', 'was', 'no', 'crime', 'except'],
#  ['was', 'no', 'crime', 'except', 'on'],
#  ['no', 'crime', 'except', 'on', 'the'],
#  ['crime', 'except', 'on', 'the', 'other'],
#  ['except', 'on', 'the', 'other', 'side'],
#  ['on', 'the', 'other', 'side', 'incredibly'],
#  ['the', 'other', 'side', 'incredibly', 'not'],
#  ['other', 'side', 'incredibly', 'not', 'covered'],
#  ['side', 'incredibly', 'not', 'covered', 'in'],
#  ['incredibly', 'not', 'covered', 'in', 'the'],
#  ['not', 'covered', 'in', 'the', 'report'],
#  ['covered', 'in', 'the', 'report', 'and'],
#  ['in', 'the', 'report', 'and', 'no'],
#  ['the', 'report', 'and', 'no', 'obstruction'],
#  ['report', 'and', 'no', 'obstruction', 'bob'],
#  ['and', 'no', 'obstruction', 'bob', 'mueller'],
#  ['no', 'obstruction', 'bob', 'mueller', 'should'],
#  ['obstruction', 'bob', 'mueller', 'should', 'not'],
#  ['bob', 'mueller', 'should', 'not', 'testify'],
#  ['mueller', 'should', 'not', 'testify', 'no'],
#  ['should', 'not', 'testify', 'no', '<Unknown>'],
#  ['not', 'testify', 'no', '<Unknown>', 'for'],
#  ['testify', 'no', '<Unknown>', 'for', 'the'],
#  ['rep', 'alexandria', 'ocasio', 'cortez', 'is'],
#  ['alexandria', 'ocasio', 'cortez', 'is', 'correct'],
#  ['ocasio', 'cortez', 'is', 'correct', 'the'],
#  ['cortez', 'is', 'correct', 'the', 'va'],
#  ['is', 'correct', 'the', 'va', 'is'],
#  ['correct', 'the', 'va', 'is', 'not'],
#  ['the', 'va', 'is', 'not', 'broken'],
#  ['va', 'is', 'not', 'broken', 'it'],
#  ['is', 'not', 'broken', 'it', 'is'],
#  ['not', 'broken', 'it', 'is', 'doing'],
#  ['broken', 'it', 'is', 'doing', 'great'],
#  ['it', 'is', 'doing', 'great', 'but'],
#  ['is', 'doing', 'great', 'but', 'that'],
#  ['doing', 'great', 'but', 'that', 'is'],
#  ['great', 'but', 'that', 'is', 'only'],
#  ['but', 'that', 'is', 'only', 'because'],
#  ['that', 'is', 'only', 'because', 'of'],
#  ['is', 'only', 'because', 'of', 'the'],
#  ['only', 'because', 'of', 'the', 'trump'],
#  ['because', 'of', 'the', 'trump', 'administration'],
#  ['of', 'the', 'trump', 'administration', 'we'],
#  ['the', 'trump', 'administration', 'we', 'got'],
#  ['trump', 'administration', 'we', 'got', 'veterans'],
#  ['administration', 'we', 'got', 'veterans', 'choice'],
#  ['we', 'got', 'veterans', 'choice', 'accountability'],
#  ['got', 'veterans', 'choice', 'accountability', 'passed'],
#  ['veterans', 'choice', 'accountability', 'passed', 'president'],
#  ['choice', 'accountability', 'passed', 'president', 'trump'],
#  ['accountability', 'passed', 'president', 'trump', 'deserves'],
#  ['passed', 'president', 'trump', 'deserves', 'a'],
#  ['president', 'trump', 'deserves', 'a', 'lot'],
#  ['trump', 'deserves', 'a', 'lot', 'of'],
#  ['deserves', 'a', 'lot', 'of', 'credit'],
#  ['a', 'lot', 'of', 'credit', 'dan'],
#  ['lot', 'of', 'credit', 'dan', 'caldwell'],
#  ['of', 'credit', 'dan', 'caldwell', 'concerned'],
#  ['credit', 'dan', 'caldwell', 'concerned', 'veterans'],
#  ['dan', 'caldwell', 'concerned', 'veterans', 'of'],
#  ['report', 'whistleblower', 'never', 'disclosed', 'contact'],
#  ['whistleblower', 'never', 'disclosed', 'contact', 'with'],
#  ['never', 'disclosed', 'contact', 'with', 'house'],
#  ['disclosed', 'contact', 'with', 'house', 'intel'],
#  ['contact', 'with', 'house', 'intel', 'panel'],
#  ['with', 'house', 'intel', 'panel', 'to'],
#  ['house', 'intel', 'panel', 'to', 'inspector'],
#  ['i', 'will', 'be', 'in', 'washington'],
#  ['will', 'be', 'in', 'washington', 'd'],
#  ['be', 'in', 'washington', 'd', 'c'],
#  ['in', 'washington', 'd', 'c', 'on'],
#  ['washington', 'd', 'c', 'on', 'wednesday'],
#  ['d', 'c', 'on', 'wednesday', 'p'],
#  ['c', 'on', 'wednesday', 'p', 'm'],
#  ['on', 'wednesday', 'p', 'm', 'in'],
#  ['wednesday', 'p', 'm', 'in', 'front'],
#  ['p', 'm', 'in', 'front', 'of'],
#  ['m', 'in', 'front', 'of', 'the'],
#  ['in', 'front', 'of', 'the', 'capitol'],
#  ['front', 'of', 'the', 'capitol', 'to'],
#  ['of', 'the', 'capitol', 'to', 'protest'],
#  ['the', 'capitol', 'to', 'protest', 'the'],
#  ['capitol', 'to', 'protest', 'the', 'horrible'],
#  ['to', 'protest', 'the', 'horrible', 'and'],
#  ['protest', 'the', 'horrible', 'and', 'incompetent'],
#  ['the', 'horrible', 'and', 'incompetent', 'deal'],
#  ['horrible', 'and', 'incompetent', 'deal', 'being'],
#  ['and', 'incompetent', 'deal', 'being', 'made'],
#  ['incompetent', 'deal', 'being', 'made', 'with'],
#  ['<Unknown>', 'and', 'friendship', 'was', 'formed'],
#  ['and', 'friendship', 'was', 'formed', 'but'],
#  ['friendship', 'was', 'formed', 'but', 'only'],
#  ['was', 'formed', 'but', 'only', 'time'],
#  ['formed', 'but', 'only', 'time', 'will'],
#  ['but', 'only', 'time', 'will', 'tell'],
#  ['only', 'time', 'will', 'tell', 'on'],
#  ['in', 'the', 'basement', 'of', 'the'],
#  ['the', 'basement', 'of', 'the', 'united'],
#  ['basement', 'of', 'the', 'united', 'states'],
#  ['of', 'the', 'united', 'states', 'capitol'],
#  ['the', 'united', 'states', 'capitol', 'they'],
#  ['united', 'states', 'capitol', 'they', 'cannot'],
#  ['states', 'capitol', 'they', 'cannot', 'win'],
#  ['capitol', 'they', 'cannot', 'win', 'at'],
#  ['they', 'cannot', 'win', 'at', 'the'],
#  ['cannot', 'win', 'at', 'the', 'ballot'],
#  ['win', 'at', 'the', 'ballot', 'box'],
#  ['at', 'the', 'ballot', 'box', 'their'],
#  ['the', 'ballot', 'box', 'their', 'sham'],
#  ['ballot', 'box', 'their', 'sham', 'for'],
#  ['box', 'their', 'sham', 'for', 'the'],
#  ['their', 'sham', 'for', 'the', 'past'],
#  ['sham', 'for', 'the', 'past', 'years'],
#  ['for', 'the', 'past', 'years', 'continues'],
#  ['the', 'past', 'years', 'continues', 'the'],
#  ['past', 'years', 'continues', 'the', 'good'],
#  ['years', 'continues', 'the', 'good', 'news'],
#  ['continues', 'the', 'good', 'news', 'is'],
#  ['the', 'good', 'news', 'is', 'that'],
#  ['good', 'news', 'is', 'that', 'the'],
#  ['news', 'is', 'that', 'the', 'american'],
#  ['is', 'that', 'the', 'american', 'people'],
#  ['that', 'the', 'american', 'people', 'get'],
#  ['the', 'american', 'people', 'get', 'it'],
#  ['american', 'people', 'get', 'it', 'which'],
#  ['people', 'get', 'it', 'which', 'will'],
#  ['get', 'it', 'which', 'will', 'be'],
#  ['it', 'which', 'will', 'be', 'proven'],
#  ['which', 'will', 'be', 'proven', 'once'],
#  ['will', 'be', 'proven', 'once', 'again'],
#  ['be', 'proven', 'once', 'again', 'on'],
#  ['trump', 'will', 'win', 'the', 'debate'],
#  ['will', 'win', 'the', 'debate', 'like'],
#  ['win', 'the', 'debate', 'like', 'he'],
#  ['the', 'debate', 'like', 'he', 'has'],
#  ['debate', 'like', 'he', 'has', 'won'],
#  ['like', 'he', 'has', 'won', 'all'],
#  ['he', 'has', 'won', 'all', 'the'],
#  ['has', 'won', 'all', 'the', 'others'],
#  ['won', 'all', 'the', 'others', 'he'],
#  ['all', 'the', 'others', 'he', 'is'],
#  ['the', 'others', 'he', 'is', 'heads'],
#  ['others', 'he', 'is', 'heads', 'above'],
#  ['he', 'is', 'heads', 'above', 'the'],
#  ['is', 'heads', 'above', 'the', 'rest'],
#  ['heads', 'above', 'the', 'rest', 'votetrump'],
#  ['i', 'always', 'felt', 'i', 'would'],
#  ['always', 'felt', 'i', 'would', 'be'],
#  ['felt', 'i', 'would', 'be', 'running'],
#  ['i', 'would', 'be', 'running', 'and'],
#  ['would', 'be', 'running', 'and', 'winning'],
#  ['be', 'running', 'and', 'winning', 'against'],
#  ['running', 'and', 'winning', 'against', 'bernie'],
#  ['and', 'winning', 'against', 'bernie', 'sanders'],
#  ['winning', 'against', 'bernie', 'sanders', 'not'],
#  ['against', 'bernie', 'sanders', 'not', 'crooked'],
#  ['bernie', 'sanders', 'not', 'crooked', 'h'],
#  ['sanders', 'not', 'crooked', 'h', 'without'],
#  ['not', 'crooked', 'h', 'without', 'cheating'],
#  ['crooked', 'h', 'without', 'cheating', 'i'],
#  ['h', 'without', 'cheating', 'i', 'was'],
#  ['i', 'often', 'stated', 'one', 'way'],
#  ['often', 'stated', 'one', 'way', 'or'],
#  ['stated', 'one', 'way', 'or', 'the'],
#  ['one', 'way', 'or', 'the', 'other'],
#  ['way', 'or', 'the', 'other', 'mexico'],
#  ['or', 'the', 'other', 'mexico', 'is'],
#  ['the', 'other', 'mexico', 'is', 'going'],
#  ['other', 'mexico', 'is', 'going', 'to'],
#  ['mexico', 'is', 'going', 'to', 'pay'],
#  ['is', 'going', 'to', 'pay', 'for'],
#  ['going', 'to', 'pay', 'for', 'the'],
#  ['to', 'pay', 'for', 'the', 'wall'],
#  ['pay', 'for', 'the', 'wall', 'this'],
#  ['for', 'the', 'wall', 'this', 'has'],
#  ['the', 'wall', 'this', 'has', 'never'],
#  ['wall', 'this', 'has', 'never', 'changed'],
#  ['this', 'has', 'never', 'changed', 'our'],
#  ['has', 'never', 'changed', 'our', 'new'],
#  ['never', 'changed', 'our', 'new', 'deal'],
#  ['changed', 'our', 'new', 'deal', 'with'],
#  ['our', 'new', 'deal', 'with', 'mexico'],
#  ['new', 'deal', 'with', 'mexico', 'and'],
#  ['deal', 'with', 'mexico', 'and', 'canada'],
#  ['with', 'mexico', 'and', 'canada', 'the'],
#  ['mexico', 'and', 'canada', 'the', 'usmca'],
#  ['and', 'canada', 'the', 'usmca', 'is'],
#  ['canada', 'the', 'usmca', 'is', 'so'],
#  ['the', 'usmca', 'is', 'so', 'much'],
#  ['usmca', 'is', 'so', 'much', 'better'],
#  ['is', 'so', 'much', 'better', 'than'],
#  ['so', 'much', 'better', 'than', 'the'],
#  ['much', 'better', 'than', 'the', 'old'],
#  ['better', 'than', 'the', 'old', 'very'],
#  ['than', 'the', 'old', 'very', 'costly'],
#  ['the', 'old', 'very', 'costly', 'anti'],
#  ['old', 'very', 'costly', 'anti', 'usa'],
#  ['very', 'costly', 'anti', 'usa', 'nafta'],
#  ['costly', 'anti', 'usa', 'nafta', 'deal'],
#  ['anti', 'usa', 'nafta', 'deal', 'that'],
#  ['usa', 'nafta', 'deal', 'that', 'just'],
#  ['nafta', 'deal', 'that', 'just', 'by'],
#  ['deal', 'that', 'just', 'by', 'the'],
#  ['that', 'just', 'by', 'the', 'money'],
#  ['just', 'by', 'the', 'money', 'we'],
#  ['by', 'the', 'money', 'we', 'save'],
#  ['the', 'money', 'we', 'save', 'mexico'],
#  ['money', 'we', 'save', 'mexico', 'is'],
#  ['we', 'save', 'mexico', 'is', 'paying'],
#  ['save', 'mexico', 'is', 'paying', 'for'],
#  ['mexico', 'is', 'paying', 'for', 'the'],
#  ['my', 'h', 'b', 'reform', 'plan'],
#  ['h', 'b', 'reform', 'plan', 'will'],
#  ['b', 'reform', 'plan', 'will', 'transform'],
#  ['reform', 'plan', 'will', 'transform', 'program'],
#  ['plan', 'will', 'transform', 'program', 'so'],
#  ['will', 'transform', 'program', 'so', 'it'],
#  ['transform', 'program', 'so', 'it', 'delivers'],
#  ['program', 'so', 'it', 'delivers', 'for'],
#  ['so', 'it', 'delivers', 'for', 'country'],
#  ['it', 'delivers', 'for', 'country', 'not'],
#  ['delivers', 'for', 'country', 'not', 'lobbyists'],
#  ['for', 'country', 'not', 'lobbyists', 'will'],
#  ['country', 'not', 'lobbyists', 'will', 'have'],
#  ['not', 'lobbyists', 'will', 'have', 'bipartisan'],
#  ['getting', 'ready', 'to', 'lift', 'off'],
#  ['ready', 'to', 'lift', 'off', 'for'],
#  ['to', 'lift', 'off', 'for', 'laredo'],
#  ['lift', 'off', 'for', 'laredo', 'will'],
#  ['off', 'for', 'laredo', 'will', 'land'],
#  ['for', 'laredo', 'will', 'land', 'at'],
#  ['laredo', 'will', 'land', 'at', '<Unknown>'],
#  ['will', 'land', 'at', '<Unknown>', 'p'],
#  ['land', 'at', '<Unknown>', 'p', 'm'],
#  ['at', '<Unknown>', 'p', 'm', 'should'],
#  ['<Unknown>', 'p', 'm', 'should', 'be'],
#  ['p', 'm', 'should', 'be', 'exciting'],
#  ['m', 'should', 'be', 'exciting', 'and'],
#  ['will', 'be', 'interviewed', 'on', 'on'],
#  ['be', 'interviewed', 'on', 'on', 'at'],
#  ['interviewed', 'on', 'on', 'at', 'a'],
#  ['gina', 'haspel', 'my', 'highly', 'respected'],
#  ['haspel', 'my', 'highly', 'respected', 'nominee'],
#  ['my', 'highly', 'respected', 'nominee', 'to'],
#  ['highly', 'respected', 'nominee', 'to', 'lead'],
#  ['respected', 'nominee', 'to', 'lead', 'the'],
#  ['nominee', 'to', 'lead', 'the', 'cia'],
#  ['to', 'lead', 'the', 'cia', 'is'],
#  ['lead', 'the', 'cia', 'is', 'being'],
#  ['the', 'cia', 'is', 'being', 'praised'],
#  ['cia', 'is', 'being', 'praised', 'for'],
#  ['is', 'being', 'praised', 'for', 'the'],
#  ['being', 'praised', 'for', 'the', 'fact'],
#  ['praised', 'for', 'the', 'fact', 'that'],
#  ['for', 'the', 'fact', 'that', 'she'],
#  ['the', 'fact', 'that', 'she', 'has'],
#  ['fact', 'that', 'she', 'has', 'been'],
#  ['that', 'she', 'has', 'been', 'and'],
#  ['she', 'has', 'been', 'and', '<Unknown>'],
#  ['has', 'been', 'and', '<Unknown>', 'will'],
#  ['been', 'and', '<Unknown>', 'will', 'be'],
#  ['and', '<Unknown>', 'will', 'be', 'tough'],
#  ['<Unknown>', 'will', 'be', 'tough', 'on'],
#  ['will', 'be', 'tough', 'on', 'terror'],
#  ['be', 'tough', 'on', 'terror', 'this'],
#  ['tough', 'on', 'terror', 'this', 'is'],
#  ['on', 'terror', 'this', 'is', 'a'],
#  ['terror', 'this', 'is', 'a', 'woman'],
#  ['this', 'is', 'a', 'woman', 'who'],
#  ['is', 'a', 'woman', 'who', 'has'],
#  ['a', 'woman', 'who', 'has', 'been'],
#  ['woman', 'who', 'has', 'been', 'a'],
#  ['who', 'has', 'been', 'a', 'leader'],
#  ['has', 'been', 'a', 'leader', 'wherever'],
#  ['been', 'a', 'leader', 'wherever', 'she'],
#  ['a', 'leader', 'wherever', 'she', 'has'],
#  ['leader', 'wherever', 'she', 'has', 'gone'],
#  ['wherever', 'she', 'has', 'gone', 'the'],
#  ['she', 'has', 'gone', 'the', 'cia'],
#  ['has', 'gone', 'the', 'cia', 'wants'],
#  ['gone', 'the', 'cia', 'wants', 'her'],
#  ['the', 'cia', 'wants', 'her', 'to'],
#  ['cia', 'wants', 'her', 'to', 'lead'],
#  ['wants', 'her', 'to', 'lead', 'them'],
#  ['her', 'to', 'lead', 'them', 'into'],
#  ['to', 'lead', 'them', 'into', 'america'],
#  ['lead', 'them', 'into', 'america', 's'],
#  ['them', 'into', 'america', 's', 'bright'],
#  ['into', 'america', 's', 'bright', 'and'],
#  ['america', 's', 'bright', 'and', 'glorious'],
#  ['just', 'spoke', 'to', 'prime', 'minister'],
#  ['spoke', 'to', 'prime', 'minister', '<Unknown>'],
#  ['to', 'prime', 'minister', '<Unknown>', 'ahmed'],
#  ['prime', 'minister', '<Unknown>', 'ahmed', 'ali'],
#  ['minister', '<Unknown>', 'ahmed', 'ali', 'of'],
#  ['<Unknown>', 'ahmed', 'ali', 'of', 'ethiopia'],
#  ['ahmed', 'ali', 'of', 'ethiopia', 'his'],
#  ['ali', 'of', 'ethiopia', 'his', 'country'],
#  ['of', 'ethiopia', 'his', 'country', 'needs'],
#  ['ethiopia', 'his', 'country', 'needs', 'ventilators'],
#  ['his', 'country', 'needs', 'ventilators', 'and'],
#  ['country', 'needs', 'ventilators', 'and', 'the'],
#  ['needs', 'ventilators', 'and', 'the', 'u'],
#  ['ventilators', 'and', 'the', 'u', 's'],
#  ['and', 'the', 'u', 's', 'is'],
#  ['the', 'u', 's', 'is', 'in'],
#  ['u', 's', 'is', 'in', 'good'],
#  ['s', 'is', 'in', 'good', 'position'],
#  ['is', 'in', 'good', 'position', 'to'],
#  ['in', 'good', 'position', 'to', 'help'],
#  ['good', 'position', 'to', 'help', 'him'],
#  ['position', 'to', 'help', 'him', 'we'],
#  ['thank', 'you', 'police', 'force', 'for'],
#  ['you', 'police', 'force', 'for', 'your'],
#  ['police', 'force', 'for', 'your', 'efforts'],
#  ['force', 'for', 'your', 'efforts', 'of'],
#  ['for', 'your', 'efforts', 'of', 'protecting'],
#  ['your', 'efforts', 'of', 'protecting', 'donald'],
#  ['efforts', 'of', 'protecting', 'donald', 'trump'],
#  ['of', 'protecting', 'donald', 'trump', 'we'],
#  ['protecting', 'donald', 'trump', 'we', 'love'],
#  ['donald', 'trump', 'we', 'love', 'you'],
#  ['trump', 'we', 'love', 'you', 'for'],
#  ['we', 'love', 'you', 'for', 'this'],
#  ['love', 'you', 'for', 'this', 'god'],
#  ['you', 'for', 'this', 'god', 'bless'],
#  ['and', 'lyin', 'ted', 'cruz', 'are'],
#  ['lyin', 'ted', 'cruz', 'are', 'two'],
#  ['ted', 'cruz', 'are', 'two', 'politicians'],
#  ['cruz', 'are', 'two', 'politicians', 'who'],
#  ['are', 'two', 'politicians', 'who', 'are'],
#  ['two', 'politicians', 'who', 'are', 'very'],
#  ['politicians', 'who', 'are', 'very', 'much'],
#  ['who', 'are', 'very', 'much', 'alike'],
#  ['are', 'very', 'much', 'alike', 'all'],
#  ['very', 'much', 'alike', 'all', 'talk'],
#  ['much', 'alike', 'all', 'talk', 'and'],
#  ['alike', 'all', 'talk', 'and', 'no'],
#  ['all', 'talk', 'and', 'no', 'action'],
#  ['talk', 'and', 'no', 'action', 'both'],
#  ['and', 'no', 'action', 'both', 'talk'],
#  ['no', 'action', 'both', 'talk', 'about'],
#  ['action', 'both', 'talk', 'about', 'isis'],
#  ['both', 'talk', 'about', 'isis', 'do'],
#  ['despite', 'the', 'disgusting', 'illegal', 'and'],
#  ['the', 'disgusting', 'illegal', 'and', 'unwarranted'],
#  ['disgusting', 'illegal', 'and', 'unwarranted', 'witch'],
#  ['illegal', 'and', 'unwarranted', 'witch', 'hunt'],
#  ['and', 'unwarranted', 'witch', 'hunt', 'we'],
#  ['unwarranted', 'witch', 'hunt', 'we', 'have'],
#  ['witch', 'hunt', 'we', 'have', 'had'],
#  ['hunt', 'we', 'have', 'had', 'the'],
#  ['we', 'have', 'had', 'the', 'most'],
#  ['have', 'had', 'the', 'most', 'successful'],
#  ['had', 'the', 'most', 'successful', 'first'],
#  ['the', 'most', 'successful', 'first', 'month'],
#  ['most', 'successful', 'first', 'month', 'administration'],
#  ['successful', 'first', 'month', 'administration', 'in'],
#  ['first', 'month', 'administration', 'in', 'u'],
#  ['month', 'administration', 'in', 'u', 's'],
#  ['administration', 'in', 'u', 's', 'history'],
#  ['in', 'u', 's', 'history', 'by'],
#  ['u', 's', 'history', 'by', 'far'],
#  ['s', 'history', 'by', 'far', 'sorry'],
#  ['history', 'by', 'far', 'sorry', 'to'],
#  ['by', 'far', 'sorry', 'to', 'the'],
#  ['far', 'sorry', 'to', 'the', 'fake'],
#  ['sorry', 'to', 'the', 'fake', 'news'],
#  ['to', 'the', 'fake', 'news', 'media'],
#  ['the', 'fake', 'news', 'media', 'and'],
#  ['fake', 'news', 'media', 'and', 'haters'],
#  ['news', 'media', 'and', 'haters', 'but'],
#  ['media', 'and', 'haters', 'but', 'that'],
#  ['and', 'haters', 'but', 'that', 's'],
#  ['haters', 'but', 'that', 's', 'the'],
#  ['but', 'that', 's', 'the', 'way'],
#  ['that', 's', 'the', 'way', 'it'],
#  ['obama', 'left', 'our', 'american', 'hostages'],
#  ['left', 'our', 'american', 'hostages', 'in'],
#  ['our', 'american', 'hostages', 'in', 'iran'],
#  ['american', 'hostages', 'in', 'iran', 'trump'],
#  ['hostages', 'in', 'iran', 'trump', 'sadly'],
#  ['in', 'iran', 'trump', 'sadly', 'so'],
#  ['for', 'the', 'great', 'people', 'of'],
#  ['the', 'great', 'people', 'of', 'iowa'],
#  ['great', 'people', 'of', 'iowa', 'find'],
#  ['people', 'of', 'iowa', 'find', 'your'],
#  ['of', 'iowa', 'find', 'your', 'iacaucus'],
#  ['iowa', 'find', 'your', 'iacaucus', 'location'],
#  ['find', 'your', 'iacaucus', 'location', 'at'],
#  ['your', 'iacaucus', 'location', 'at', 'so'],
#  ['iacaucus', 'location', 'at', 'so', 'important'],
#  ['location', 'at', 'so', 'important', 'to'],
#  ['at', 'so', 'important', 'to', 'vote'],
#  ['katie', '<Unknown>', 'the', 'third', 'rate'],
#  ['<Unknown>', 'the', 'third', 'rate', 'reporter'],
#  ['the', 'third', 'rate', 'reporter', 'who'],
#  ['third', 'rate', 'reporter', 'who', 'has'],
#  ['rate', 'reporter', 'who', 'has', 'been'],
#  ['reporter', 'who', 'has', 'been', 'largely'],
#  ['who', 'has', 'been', 'largely', 'forgotten'],
#  ['has', 'been', 'largely', 'forgotten', 'should'],
#  ['been', 'largely', 'forgotten', 'should', 'be'],
#  ['largely', 'forgotten', 'should', 'be', 'ashamed'],
#  ['forgotten', 'should', 'be', 'ashamed', 'of'],
#  ['should', 'be', 'ashamed', 'of', 'herself'],
#  ['be', 'ashamed', 'of', 'herself', 'for'],
#  ['ashamed', 'of', 'herself', 'for', 'the'],
#  ['of', 'herself', 'for', 'the', 'fraudulent'],
#  ['herself', 'for', 'the', 'fraudulent', '<Unknown>'],
#  ['for', 'the', 'fraudulent', '<Unknown>', 'of'],
#  ['the', 'fraudulent', '<Unknown>', 'of', 'her'],
#  ['just', 'arrived', 'in', '<Unknown>', 'with'],
#  ['arrived', 'in', '<Unknown>', 'with', 'melania'],
#  ['in', '<Unknown>', 'with', 'melania', 'g'],
#  ['<Unknown>', 'with', 'melania', 'g', 'summit'],
#  ['this', 'is', 'an', 'illegally', 'brought'],
#  ['is', 'an', 'illegally', 'brought', 'rigged'],
#  ['an', 'illegally', 'brought', 'rigged', 'witch'],
#  ['illegally', 'brought', 'rigged', 'witch', 'hunt'],
#  ['brought', 'rigged', 'witch', 'hunt', 'run'],
#  ['rigged', 'witch', 'hunt', 'run', 'by'],
#  ['witch', 'hunt', 'run', 'by', 'people'],
#  ['hunt', 'run', 'by', 'people', 'who'],
#  ['run', 'by', 'people', 'who', 'are'],
#  ['by', 'people', 'who', 'are', 'totally'],
#  ['people', 'who', 'are', 'totally', 'corrupt'],
#  ['who', 'are', 'totally', 'corrupt', 'and'],
#  ['are', 'totally', 'corrupt', 'and', 'or'],
#  ['totally', 'corrupt', 'and', 'or', 'conflicted'],
#  ['corrupt', 'and', 'or', 'conflicted', 'it'],
#  ['and', 'or', 'conflicted', 'it', 'was'],
#  ['or', 'conflicted', 'it', 'was', 'started'],
#  ['conflicted', 'it', 'was', 'started', 'and'],
#  ['it', 'was', 'started', 'and', 'paid'],
#  ['was', 'started', 'and', 'paid', 'for'],
#  ['started', 'and', 'paid', 'for', 'by'],
#  ['and', 'paid', 'for', 'by', 'crooked'],
#  ['paid', 'for', 'by', 'crooked', 'hillary'],
#  ['for', 'by', 'crooked', 'hillary', 'and'],
#  ['by', 'crooked', 'hillary', 'and', 'the'],
#  ['crooked', 'hillary', 'and', 'the', 'democrats'],
#  ['hillary', 'and', 'the', 'democrats', 'phony'],
#  ['and', 'the', 'democrats', 'phony', 'dossier'],
#  ['the', 'democrats', 'phony', 'dossier', 'fisa'],
#  ['democrats', 'phony', 'dossier', 'fisa', 'disgrace'],
#  ['phony', 'dossier', 'fisa', 'disgrace', 'and'],
#  ['dossier', 'fisa', 'disgrace', 'and', 'so'],
#  ['fisa', 'disgrace', 'and', 'so', 'many'],
#  ['disgrace', 'and', 'so', 'many', 'lying'],
#  ['and', 'so', 'many', 'lying', 'and'],
#  ['so', 'many', 'lying', 'and', 'dishonest'],
#  ['many', 'lying', 'and', 'dishonest', 'people'],
#  ['lying', 'and', 'dishonest', 'people', 'already'],
#  ['and', 'dishonest', 'people', 'already', 'fired'],
#  ['dishonest', 'people', 'already', 'fired', 'angry'],
#  ['people', 'already', 'fired', 'angry', 'dems'],
#  ['already', 'fired', 'angry', 'dems', 'stay'],
#  ['i', 'have', 'just', 'given', 'an'],
#  ['have', 'just', 'given', 'an', 'order'],
#  ['just', 'given', 'an', 'order', 'for'],
#  ['given', 'an', 'order', 'for', 'our'],
#  ['an', 'order', 'for', 'our', 'national'],
#  ['order', 'for', 'our', 'national', 'guard'],
#  ['for', 'our', 'national', 'guard', 'to'],
#  ['our', 'national', 'guard', 'to', 'start'],
#  ['national', 'guard', 'to', 'start', 'the'],
#  ['guard', 'to', 'start', 'the', 'process'],
#  ['to', 'start', 'the', 'process', 'of'],
#  ['start', 'the', 'process', 'of', 'withdrawing'],
#  ['the', 'process', 'of', 'withdrawing', 'from'],
#  ['process', 'of', 'withdrawing', 'from', 'washington'],
#  ['of', 'withdrawing', 'from', 'washington', 'd'],
#  ['withdrawing', 'from', 'washington', 'd', 'c'],
#  ['from', 'washington', 'd', 'c', 'now'],
#  ['washington', 'd', 'c', 'now', 'that'],
#  ['d', 'c', 'now', 'that', 'everything'],
#  ['c', 'now', 'that', 'everything', 'is'],
#  ['now', 'that', 'everything', 'is', 'under'],
#  ['that', 'everything', 'is', 'under', 'perfect'],
#  ['everything', 'is', 'under', 'perfect', 'control'],
#  ['is', 'under', 'perfect', 'control', 'they'],
#  ['under', 'perfect', 'control', 'they', 'will'],
#  ['perfect', 'control', 'they', 'will', 'be'],
#  ['control', 'they', 'will', 'be', 'going'],
#  ['they', 'will', 'be', 'going', 'home'],
#  ['will', 'be', 'going', 'home', 'but'],
#  ['be', 'going', 'home', 'but', 'can'],
#  ['going', 'home', 'but', 'can', 'quickly'],
#  ['home', 'but', 'can', 'quickly', 'return'],
#  ['but', 'can', 'quickly', 'return', 'if'],
#  ['can', 'quickly', 'return', 'if', 'needed'],
#  ['quickly', 'return', 'if', 'needed', 'far'],
#  ['return', 'if', 'needed', 'far', 'fewer'],
#  ['if', 'needed', 'far', 'fewer', 'protesters'],
#  ['needed', 'far', 'fewer', 'protesters', 'showed'],
#  ['far', 'fewer', 'protesters', 'showed', 'up'],
#  ['fewer', 'protesters', 'showed', 'up', 'last'],
#  ['protesters', 'showed', 'up', 'last', 'night'],
#  ['showed', 'up', 'last', 'night', 'than'],
#  ['via', 'cnn', 'trump', 'now', 'leads'],
#  ['cnn', 'trump', 'now', 'leads', 'in'],
#  ['trump', 'now', 'leads', 'in', 'odds'],
#  ['now', 'leads', 'in', 'odds', 'to'],
#  ['leads', 'in', 'odds', 'to', 'win'],
#  ['in', 'odds', 'to', 'win', 'gop'],
#  ['hopefully', 'mitch', 'mcconnell', 'will', 'ask'],
#  ['mitch', 'mcconnell', 'will', 'ask', 'for'],
#  ['mcconnell', 'will', 'ask', 'for', 'a'],
#  ['will', 'ask', 'for', 'a', 'vote'],
#  ['ask', 'for', 'a', 'vote', 'on'],
#  ['for', 'a', 'vote', 'on', 'criminal'],
#  ['a', 'vote', 'on', 'criminal', 'justice'],
#  ['vote', 'on', 'criminal', 'justice', 'reform'],
#  ['on', 'criminal', 'justice', 'reform', 'it'],
#  ['criminal', 'justice', 'reform', 'it', 'is'],
#  ['justice', 'reform', 'it', 'is', 'extremely'],
#  ['reform', 'it', 'is', 'extremely', 'popular'],
#  ['it', 'is', 'extremely', 'popular', 'and'],
#  ['is', 'extremely', 'popular', 'and', 'has'],
#  ['extremely', 'popular', 'and', 'has', 'strong'],
#  ['popular', 'and', 'has', 'strong', 'bipartisan'],
#  ['and', 'has', 'strong', 'bipartisan', 'support'],
#  ['has', 'strong', 'bipartisan', 'support', 'it'],
#  ['strong', 'bipartisan', 'support', 'it', 'will'],
#  ['bipartisan', 'support', 'it', 'will', 'also'],
#  ['support', 'it', 'will', 'also', 'help'],
#  ['it', 'will', 'also', 'help', 'a'],
#  ['will', 'also', 'help', 'a', 'lot'],
#  ['also', 'help', 'a', 'lot', 'of'],
#  ['help', 'a', 'lot', 'of', 'people'],
#  ['a', 'lot', 'of', 'people', 'save'],
#  ['lot', 'of', 'people', 'save', 'taxpayer'],
#  ['of', 'people', 'save', 'taxpayer', 'dollars'],
#  ['people', 'save', 'taxpayer', 'dollars', 'and'],
#  ['save', 'taxpayer', 'dollars', 'and', 'keep'],
#  ['taxpayer', 'dollars', 'and', 'keep', 'our'],
#  ['dollars', 'and', 'keep', 'our', 'communities'],
#  ['and', 'keep', 'our', 'communities', 'safe'],
#  ['keep', 'our', 'communities', 'safe', 'go'],
#  ['our', 'communities', 'safe', 'go', 'for'],
#  ['communities', 'safe', 'go', 'for', 'it'],
#  ['dems', 'totally', 'control', 'the', 'u'],
#  ['totally', 'control', 'the', 'u', 's'],
#  ['control', 'the', 'u', 's', 'senate'],
#  ['the', 'u', 's', 'senate', 'many'],
#  ['u', 's', 'senate', 'many', 'great'],
#  ['s', 'senate', 'many', 'great', 'republican'],
#  ['senate', 'many', 'great', 'republican', 'bills'],
#  ['many', 'great', 'republican', 'bills', 'will'],
#  ['great', 'republican', 'bills', 'will', 'never'],
#  ['republican', 'bills', 'will', 'never', 'pass'],
#  ['bills', 'will', 'never', 'pass', 'like'],
#  ['will', 'never', 'pass', 'like', 'kate'],
#  ['never', 'pass', 'like', 'kate', 's'],
#  ['pass', 'like', 'kate', 's', 'law'],
#  ['like', 'kate', 's', 'law', 'and'],
#  ['kate', 's', 'law', 'and', 'complete'],
#  ['s', 'law', 'and', 'complete', 'healthcare'],
#  ['law', 'and', 'complete', 'healthcare', 'get'],
#  ['the', 'best', 'thing', 'ever', 'to'],
#  ['best', 'thing', 'ever', 'to', 'happen'],
#  ['thing', 'ever', 'to', 'happen', 'to'],
#  ['ever', 'to', 'happen', 'to', 'twitter'],
#  ['to', 'happen', 'to', 'twitter', 'is'],
#  ['happen', 'to', 'twitter', 'is', 'donald'],
#  ['to', 'twitter', 'is', 'donald', 'trump'],
#  ['twitter', 'is', 'donald', 'trump', 'so'],
#  ['is', 'donald', 'trump', 'so', 'true'],
#  ['donald', 'trump', 'so', 'true', 'but'],
#  ['trump', 'so', 'true', 'but', 'they'],
#  ['so', 'true', 'but', 'they', 'don'],
#  ['true', 'but', 'they', 'don', 't'],
#  ['but', 'they', 'don', 't', 'treat'],
#  ['they', 'don', 't', 'treat', 'me'],
#  ['don', 't', 'treat', 'me', 'well'],
#  ['t', 'treat', 'me', 'well', 'as'],
#  ['treat', 'me', 'well', 'as', 'a'],
#  ['me', 'well', 'as', 'a', 'republican'],
#  ['well', 'as', 'a', 'republican', 'very'],
#  ['as', 'a', 'republican', 'very', 'discriminatory'],
#  ['a', 'republican', 'very', 'discriminatory', 'hard'],
#  ['republican', 'very', 'discriminatory', 'hard', 'for'],
#  ['very', 'discriminatory', 'hard', 'for', 'people'],
#  ['discriminatory', 'hard', 'for', 'people', 'to'],
#  ['hard', 'for', 'people', 'to', 'sign'],
#  ['for', 'people', 'to', 'sign', 'on'],
#  ['people', 'to', 'sign', 'on', 'constantly'],
#  ['to', 'sign', 'on', 'constantly', 'taking'],
#  ['sign', 'on', 'constantly', 'taking', 'people'],
#  ['on', 'constantly', 'taking', 'people', 'off'],
#  ['constantly', 'taking', 'people', 'off', 'list'],
#  ['taking', 'people', 'off', 'list', 'big'],
#  ['people', 'off', 'list', 'big', 'complaints'],
#  ['off', 'list', 'big', 'complaints', 'from'],
#  ['list', 'big', 'complaints', 'from', 'many'],
#  ['big', 'complaints', 'from', 'many', 'people'],
#  ['complaints', 'from', 'many', 'people', 'different'],
#  ['from', 'many', 'people', 'different', 'names'],
#  ['many', 'people', 'different', 'names', 'over'],
#  ['said', 'such', 'nice', 'things', 'about'],
#  ['such', 'nice', 'things', 'about', 'me'],
#  ['nice', 'things', 'about', 'me', 'during'],
#  ['things', 'about', 'me', 'during', 'the'],
#  ['about', 'me', 'during', 'the', 'debate'],
#  ['me', 'during', 'the', 'debate', 'that'],
#  ['during', 'the', 'debate', 'that', 'i'],
#  ['the', 'debate', 'that', 'i', 'thought'],
#  ['debate', 'that', 'i', 'thought', 'i'],
#  ['that', 'i', 'thought', 'i', 'd'],
#  ['i', 'thought', 'i', 'd', 'do'],
#  ['thought', 'i', 'd', 'do', 'his'],
#  ['i', 'd', 'do', 'his', 'show'],
#  ['d', 'do', 'his', 'show', 'on'],
#  ['do', 'his', 'show', 'on', 'monday'],
#  ['his', 'show', 'on', 'monday', 'pm'],
#  ['just', 'watched', 'heavily', 'promoting', 'the'],
#  ['watched', 'heavily', 'promoting', 'the', 'democrats'],
#  ['heavily', 'promoting', 'the', 'democrats', 'through'],
#  ['promoting', 'the', 'democrats', 'through', 'their'],
#  ['the', 'democrats', 'through', 'their', 'dnc'],
#  ['democrats', 'through', 'their', 'dnc', 'communications'],
#  ['through', 'their', 'dnc', 'communications', 'director'],
#  ['their', 'dnc', 'communications', 'director', 'spewing'],
#  ['dnc', 'communications', 'director', 'spewing', 'out'],
#  ['communications', 'director', 'spewing', 'out', 'whatever'],
#  ['director', 'spewing', 'out', 'whatever', 'she'],
#  ['spewing', 'out', 'whatever', 'she', 'wanted'],
#  ['out', 'whatever', 'she', 'wanted', 'with'],
#  ['whatever', 'she', 'wanted', 'with', 'zero'],
#  ['she', 'wanted', 'with', 'zero', 'pushback'],
#  ['wanted', 'with', 'zero', 'pushback', 'by'],
#  ['with', 'zero', 'pushback', 'by', 'anchor'],
#  ['zero', 'pushback', 'by', 'anchor', 'terrible'],
#  ['pushback', 'by', 'anchor', 'terrible', 'considering'],
#  ['by', 'anchor', 'terrible', 'considering', 'that'],
#  ['anchor', 'terrible', 'considering', 'that', 'fox'],
#  ['terrible', 'considering', 'that', 'fox', 'couldn'],
#  ['considering', 'that', 'fox', 'couldn', 't'],
#  ['that', 'fox', 'couldn', 't', 'even'],
#  ['fox', 'couldn', 't', 'even', 'land'],
#  ['couldn', 't', 'even', 'land', 'a'],
#  ['t', 'even', 'land', 'a', 'debate'],
#  ['even', 'land', 'a', 'debate', 'the'],
#  ['land', 'a', 'debate', 'the', 'dems'],
#  ['a', 'debate', 'the', 'dems', 'give'],
#  ['debate', 'the', 'dems', 'give', 'them'],
#  ['marco', 'rubio', 'just', 'criticized', 'ted'],
#  ['rubio', 'just', 'criticized', 'ted', 'cruz'],
#  ['just', 'criticized', 'ted', 'cruz', 'for'],
#  ['criticized', 'ted', 'cruz', 'for', '<Unknown>'],
#  ['ted', 'cruz', 'for', '<Unknown>', 'tonight'],
#  ['cruz', 'for', '<Unknown>', 'tonight', 'wow'],
#  ['word', 'just', 'out', 'that', 'i'],
#  ['just', 'out', 'that', 'i', 'won'],
#  ['out', 'that', 'i', 'won', 'a'],
#  ['that', 'i', 'won', 'a', 'big'],
#  ['i', 'won', 'a', 'big', 'part'],
#  ['won', 'a', 'big', 'part', 'of'],
#  ['a', 'big', 'part', 'of', 'the'],
#  ['big', 'part', 'of', 'the', 'deep'],
#  ['part', 'of', 'the', 'deep', 'state'],
#  ['of', 'the', 'deep', 'state', 'and'],
#  ['the', 'deep', 'state', 'and', 'democrat'],
#  ['deep', 'state', 'and', 'democrat', '<Unknown>'],
#  ['state', 'and', 'democrat', '<Unknown>', 'witch'],
#  ['and', 'democrat', '<Unknown>', 'witch', 'hunt'],
#  ['democrat', '<Unknown>', 'witch', 'hunt', 'unanimous'],
#  ['<Unknown>', 'witch', 'hunt', 'unanimous', 'decision'],
#  ['witch', 'hunt', 'unanimous', 'decision', 'in'],
#  ['hunt', 'unanimous', 'decision', 'in', 'my'],
#  ['unanimous', 'decision', 'in', 'my', 'favor'],
#  ['decision', 'in', 'my', 'favor', 'from'],
#  ['in', 'my', 'favor', 'from', 'the'],
#  ['my', 'favor', 'from', 'the', 'united'],
#  ['favor', 'from', 'the', 'united', 'states'],
#  ['from', 'the', 'united', 'states', 'court'],
#  ['the', 'united', 'states', 'court', 'of'],
#  ['united', 'states', 'court', 'of', 'appeals'],
#  ['states', 'court', 'of', 'appeals', 'for'],
#  ['court', 'of', 'appeals', 'for', 'the'],
#  ['of', 'appeals', 'for', 'the', 'fourth'],
#  ['appeals', 'for', 'the', 'fourth', 'circuit'],
#  ['for', 'the', 'fourth', 'circuit', 'on'],
#  ['the', 'fourth', 'circuit', 'on', 'the'],
#  ['fourth', 'circuit', 'on', 'the', 'ridiculous'],
#  ['circuit', 'on', 'the', 'ridiculous', 'emoluments'],
#  ['on', 'the', 'ridiculous', 'emoluments', 'case'],
#  ['the', 'ridiculous', 'emoluments', 'case', 'i'],
#  ['ridiculous', 'emoluments', 'case', 'i', 'don'],
#  ['emoluments', 'case', 'i', 'don', 't'],
#  ['case', 'i', 'don', 't', 'make'],
#  ['i', 'don', 't', 'make', 'money'],
#  ['don', 't', 'make', 'money', 'but'],
#  ['t', 'make', 'money', 'but', 'lose'],
#  ['make', 'money', 'but', 'lose', 'a'],
#  ['money', 'but', 'lose', 'a', 'fortune'],
#  ...]

# %%
[' '.join(x_val[0])]
# Out:
# ['defunding police would be good']

# %% [markdown]
# # Jin Consolidation

# %%
def initialize(data_path, model_path):
    dpl = Datapipeline(data_path)
    dpl.transform()
    train, val = dpl.split_data()
    model = load_model(model_path)
    vocab, vectorizer = gen_vocab(train.values)
    
    return train, val, model, vocab, vectorizer

# %%
def tokenize(val, vocab, vectorizer):
    
    x_val, y_val = generate_text_sequences(val.values, 5, vocab)
    x_input_val = vectorizer.apply(list(map(lambda x: ' '.join(x), x_val)))
    x_input_val = tf.gather(x_input_val, [0,1,2,3,4], axis=1)
    
    return x_input_val

# %%
def generate_next_word(phrase, vectorizer, model, vocab):
    # if phrase is list of tokens
    if type(phrase) == list:
        x_input_val = vectorizer.apply([' '.join(phrase)])
    # if phrase is string
    elif type(phrase) == str:
        x_input_val = vectorizer.apply([phrase])
    x_input_val = tf.gather(x_input_val, [0,1,2,3,4], axis=1)
    prob_ = model.predict(x_input_val)
    idx = np.argmax(prob_)
    return vocab[idx]

# generate_single_tweet('the trade deficit rose to')

# %%
def generate_tweet(phrase, max_char=140):
    word = phrase[-1]
    char_count = 0
    tweet_range = np.random.randint(15,25)
    while word != '' and char_count <= max_char and len(phrase) < tweet_range:
        input_phrase = phrase[-5:]
        word = generate_next_word(input_phrase, vectorizer, model, vocab)
        if word == '':
            break
        elif word =='a' and input_phrase[-1] == 's' and input_phrase[-2] == 'u':
            word = 'usa'
            phrase.pop()
            phrase.pop()

        phrase.append(word)
        char_count = len(' '.join(phrase))
        
    return ' '.join(phrase)

# %%
# train, val, model, vocab, vectorizer = initialize('./data/realdonaldtrump.csv', 'trump_bot_bidirstack.h5')
# x_input_val = tokenize(val, vocab, vectorizer)

# phrase = ['the', 'white', 'house', 'our', 'country']

# %%
# generate_tweet(phrase)
# Out:
# 'the white house our country is doing great for the people of our country is now the be the to to usa is a great country and has my complete and'

# %% [markdown]
# Calvin - Try out functions

# %%
train, val, model, vocab, vectorizer = initialize('./data/raw/realdonaldtrump.csv', 'trump_bot.h5')
x_input_val = tokenize(val, vocab, vectorizer)
phrase = ['the', 'white', 'house', 'our', 'country']
generate_tweet(phrase)
# Out:
# WARNING:tensorflow:From <ipython-input-11-0c322ef7fd81>:4: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# 'the white house our country is doing great for the people of our country is now the be the to to'

# %%
def generatenewval(row):
    phrase = row.split()[:5]
    if len(phrase) < 5:
        return ""
    else: 
        return generate_tweet(phrase)

# %%
# val['gen_tweets'] = val['clean_text'].apply(generatenewval)

# %%
# gen_list = []
# for i in range(len(val)):
#     if i % 500 == 0:
#         print (i)
#     phrase = val.iloc[i].item().split()[:5]
#     if len(phrase) < 5:
#         gen_list.append("")
#     else:
#         gen_list.append(generate_tweet(phrase))

# %%
val_50 = val[val['clean_text'].str.len() > 50]
val_50_100 = val_50.sample(100)
val_50_100['gen_tweets'] = val_50_100['clean_text'].apply(generatenewval)

# %%
val_50_100['gen_tweets'].to_csv('generate.csv', index = False)

# %% [markdown]
# Jin Evaluation

# %%
train, val, model, vocab, vectorizer = initialize('./data/realdonaldtrump.csv', 'trump_bot_bidirstack.h5')

# %%
X_val_line, y_val_line = generate_text_sequences(val.values, 5, vocab)

# %%
df = pd.DataFrame({'precede_phrase': X_val_line, 'true_next': y_val_line})

# %%
df['pred_next'] = df['precede_phrase'].apply(lambda x: generate_next_word(x, vectorizer, model, vocab))
